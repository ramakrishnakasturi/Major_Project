# %%
import shutil
import tqdm
import numpy as np
import cv2
import os
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Model
import json
import random
import keras
import numpy as np
from keras.callbacks import EarlyStopping
from keras.layers import Input, LSTM, Dense
from keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.applications.vgg16 import VGG16
from keras.layers import Input, LSTM, Dense
from keras.models import Model, load_model
from tensorflow.keras.models import Model
from keras.utils import to_categorical
import model
import functools
import operator
import joblib
import shutil
import tqdm
import cv2
import time

# %%
test_path = "testing_data/video"

def video_to_frames(video):
    path = 'temporary_images'
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path)
    video_path = os.path.join(test_path, video)
    count = 0
    image_list = []
    # Path to video file
    cap = cv2.VideoCapture(video_path)
    while cap.isOpened():
        ret, frame = cap.read()
        if ret is False:
            break
        cv2.imwrite(os.path.join('temporary_images/', 'frame%d.jpg' % count), frame)
        image_list.append(os.path.join('temporary_images/', 'frame%d.jpg' % count))
        count += 1

    cap.release()
    cv2.destroyAllWindows()
    return image_list


def model_cnn_load():
    model = VGG16(weights="imagenet", include_top=True, input_shape=(224, 224, 3))
    out = model.layers[-2].output
    model_final = Model(inputs=model.input, outputs=out)
    return model_final


def load_image(path):
    img = cv2.imread(path)
    img = cv2.resize(img, (224, 224))
    return img


def extract_features(video, model):
    video_id = video.split(".")[0]
    print(video_id)
    print(f'Processing video {video}')
    try:
        image_list = video_to_frames(video)
        samples = np.round(np.linspace(
            0, len(image_list) - 1, 80))
        print("Images List :" , image_list)
        image_list = [image_list[int(sample)] for sample in samples]
        images = np.zeros((len(image_list), 224, 224, 3))
        for i in range(len(image_list)):
            img = load_image(image_list[i])
            images[i] = img
        images = np.array(images)
        fc_feats = model.predict(images, batch_size=128)
        img_feats = np.array(fc_feats)
        # cleanup
        shutil.rmtree('temporary_images')
        return img_feats
    except Exception as e:
        print(e)


def extract_feats_pretrained_cnn():
    model = model_cnn_load()
    print('Model loaded')

    if not os.path.isdir(os.path.join(test_path, 'feat')):
        os.mkdir(os.path.join(test_path, 'feat'))

    video_list = os.listdir(os.path.join(test_path, 'video'))
    
    #ًWhen running the script on Colab an item called '.ipynb_checkpoints' 
    #is added to the beginning of the list causing errors later on, so the next line removes it.
    #video_list.remove('.ipynb_checkpoints')
    
    for video in video_list:

        outfile = os.path.join(test_path, 'feat', video + '.npy')
        img_feats = extract_features(video, model)
        np.save(outfile, img_feats)

# %%
class VideoDescriptionRealTime(object):

    """
        Initialize the parameters for the model
        """
    def __init__(self):
        self.latent_dim = 512
        self.num_encoder_tokens = 4096
        self.num_decoder_tokens = 1500
        self.time_steps_encoder = 80
        self.max_probability = -1

        # models
        self.tokenizer, self.inf_encoder_model, self.inf_decoder_model = model.inference_model()
        
        #self.inf_decoder_model = None
        self.save_model_path = 'model_final'
        test_path = "testing_data/video"
        self.search_type = "greedy"
        self.num = 0

    def greedy_search(self, loaded_array):
        """

        :param f: the loaded numpy array after creating videos to frames and extracting features
        :return: the final sentence which has been predicted greedily
        """
        inv_map = self.index_to_word()
        states_value = self.inf_encoder_model.predict(loaded_array.reshape(-1, 80, 4096))
        target_seq = np.zeros((1, 1, 1500))
        final_sentence = ''
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        for i in range(15):
            output_tokens, h, c = self.inf_decoder_model.predict([target_seq] + states_value)
            states_value = [h, c]
            output_tokens = output_tokens.reshape(self.num_decoder_tokens)
            y_hat = np.argmax(output_tokens)
            if y_hat == 0:
                continue
            if inv_map[y_hat] is None:
                break
            if inv_map[y_hat] == 'eos':
                break
            else:
                final_sentence = final_sentence + inv_map[y_hat] + ' '
                target_seq = np.zeros((1, 1, 1500))
                target_seq[0, 0, y_hat] = 1
        return final_sentence

    def decode_sequence2bs(self, input_seq):
        states_value = self.inf_encoder_model.predict(input_seq)
        target_seq = np.zeros((1, 1, self.num_decoder_tokens))
        target_seq[0, 0, self.tokenizer.word_index['bos']] = 1
        self.beam_search(target_seq, states_value, [], [], 0)
        return decode_seq
  

    def decoded_sentence_tuning(self, decoded_sentence):
        # tuning sentence
        decode_str = []
        filter_string = ['bos', 'eos']
        uni_gram = {}
        last_string = ""
        for idx2, c in enumerate(decoded_sentence):
            if c in uni_gram:
                uni_gram[c] += 1
            else:
                uni_gram[c] = 1
            if last_string == c and idx2 > 0:
                continue
            if c in filter_string:
                continue
            if len(c) > 0:
                decode_str.append(c)
            if idx2 > 0:
                last_string = c
        return decode_str

    def index_to_word(self):
        # inverts word tokenizer
        index_to_word = {value: key for key, value in self.tokenizer.word_index.items()}
        return index_to_word

    def get_test_data(self):
        # loads the features array
        file_list = os.listdir(test_path)
        #print(file_list)
        try:
            file_list.remove('.DS_Store')
        except Exception as e:
            print(e)
        #print(file_list)
        # with open(os.path.join(test_path, 'testing.txt')) as testing_file:
            # lines = testing_file.readlines()
        # file_name = lines[self.num].strip()
        file_name = file_list[self.num]
        path = os.path.join(test_path, 'feat', file_name + '.npy')
        if os.path.exists(path):
            f = np.load(path)
        else:
            model = model_cnn_load()
            f = extract_features(file_name, model)
        if self.num < len(file_list):
            self.num += 1
        else:
            self.num = 0
        return f, file_name

    def test(self):
        X_test, filename = self.get_test_data()
        #print(X_test)
        # generate inference test outputs
        if self.search_type == 'greedy':
            sentence_predicted = self.greedy_search(X_test.reshape((-1, 80, 4096)))
        else:
            sentence_predicted = ''
            decoded_sentence = self.decode_sequence2bs(X_test.reshape((-1, 80, 4096)))
            decode_str = self.decoded_sentence_tuning(decoded_sentence)
            for d in decode_str:
                sentence_predicted = sentence_predicted + d + ' '
        # re-init max prob
        self.max_probability = -1
        return sentence_predicted, filename

    def main(self, filename, caption):
        """

        :param filename: the video to load
        :param caption: final caption
        :return:
        """
        try:
            # 1. Initialize reading video object
            cap1 = cv2.VideoCapture(os.path.join(test_path, filename))
            cap2 = cv2.VideoCapture(os.path.join(test_path, filename))
            caption = '[' + ' '.join(caption.split()[1:]) + ']'
            # 2. Cycle through pictures
            while cap1.isOpened():
                ret, frame = cap2.read()
                ret2, frame2 = cap1.read()
                if ret:
                    imS = cv2.resize(frame, (480, 300))
                    cv2.putText(imS, caption, (100, 270), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0),
                                2, cv2.LINE_4)
                    cv2.imshow("VIDEO CAPTIONING", imS)
                if ret2:
                    imS = cv2.resize(frame, (480, 300))
                    cv2.imshow("ORIGINAL", imS)
                else:
                    break

                # Quit playing
                key = cv2.waitKey(25)
                if key == 27:  # Button esc
                    break

            # 3. Free resources
            cap1.release()
            cap2.release()
            cv2.destroyAllWindows()
        except Exception as e:
            print(e)

# %%
if __name__ == "__main__":
    video_to_text = VideoDescriptionRealTime(
        
    )
    while True:
        print('.........................\nGenerating Caption:\n')
        start = time.time()
        video_caption, file = video_to_text.test()
        end = time.time()
        sentence = ''
        print(sentence)
        for text in video_caption.split():
            sentence = sentence + ' ' + text
        print('\n.........................\n')
        print(sentence)
        print('\n.........................\n')
        print('It took {:.2f} seconds to generate caption'.format(end-start))
        video_to_text.main(file, sentence)
        play_video = input('Should I play the video? ')
        if play_video.lower() == 'y':
            continue
        elif play_video.lower() == 'n':
            break
        else:
            print('Could not understand type (y) for yes and (n) for no')
            continue
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
# 2023-03-16 17:23:12.717045: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-16 17:23:12.717064: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# .........................
# Generating Caption:
#
# ufFT2BWh3BQ_0_8
# Processing video ufFT2BWh3BQ_0_8.avi
# Images List : ['temporary_images/frame0.jpg', 'temporary_images/frame1.jpg', 'temporary_images/frame2.jpg', 'temporary_images/frame3.jpg', 'temporary_images/frame4.jpg', 'temporary_images/frame5.jpg', 'temporary_images/frame6.jpg', 'temporary_images/frame7.jpg', 'temporary_images/frame8.jpg', 'temporary_images/frame9.jpg', 'temporary_images/frame10.jpg', 'temporary_images/frame11.jpg', 'temporary_images/frame12.jpg', 'temporary_images/frame13.jpg', 'temporary_images/frame14.jpg', 'temporary_images/frame15.jpg', 'temporary_images/frame16.jpg', 'temporary_images/frame17.jpg', 'temporary_images/frame18.jpg', 'temporary_images/frame19.jpg', 'temporary_images/frame20.jpg', 'temporary_images/frame21.jpg', 'temporary_images/frame22.jpg', 'temporary_images/frame23.jpg', 'temporary_images/frame24.jpg', 'temporary_images/frame25.jpg', 'temporary_images/frame26.jpg', 'temporary_images/frame27.jpg', 'temporary_images/frame28.jpg', 'temporary_images/frame29.jpg', 'temporary_images/frame30.jpg', 'temporary_images/frame31.jpg', 'temporary_images/frame32.jpg', 'temporary_images/frame33.jpg', 'temporary_images/frame34.jpg', 'temporary_images/frame35.jpg', 'temporary_images/frame36.jpg', 'temporary_images/frame37.jpg', 'temporary_images/frame38.jpg', 'temporary_images/frame39.jpg', 'temporary_images/frame40.jpg', 'temporary_images/frame41.jpg', 'temporary_images/frame42.jpg', 'temporary_images/frame43.jpg', 'temporary_images/frame44.jpg', 'temporary_images/frame45.jpg', 'temporary_images/frame46.jpg', 'temporary_images/frame47.jpg', 'temporary_images/frame48.jpg', 'temporary_images/frame49.jpg', 'temporary_images/frame50.jpg', 'temporary_images/frame51.jpg', 'temporary_images/frame52.jpg', 'temporary_images/frame53.jpg', 'temporary_images/frame54.jpg', 'temporary_images/frame55.jpg', 'temporary_images/frame56.jpg', 'temporary_images/frame57.jpg', 'temporary_images/frame58.jpg', 'temporary_images/frame59.jpg', 'temporary_images/frame60.jpg', 'temporary_images/frame61.jpg', 'temporary_images/frame62.jpg', 'temporary_images/frame63.jpg', 'temporary_images/frame64.jpg', 'temporary_images/frame65.jpg', 'temporary_images/frame66.jpg', 'temporary_images/frame67.jpg', 'temporary_images/frame68.jpg', 'temporary_images/frame69.jpg', 'temporary_images/frame70.jpg', 'temporary_images/frame71.jpg', 'temporary_images/frame72.jpg', 'temporary_images/frame73.jpg', 'temporary_images/frame74.jpg', 'temporary_images/frame75.jpg', 'temporary_images/frame76.jpg', 'temporary_images/frame77.jpg', 'temporary_images/frame78.jpg', 'temporary_images/frame79.jpg', 'temporary_images/frame80.jpg', 'temporary_images/frame81.jpg', 'temporary_images/frame82.jpg', 'temporary_images/frame83.jpg', 'temporary_images/frame84.jpg', 'temporary_images/frame85.jpg', 'temporary_images/frame86.jpg', 'temporary_images/frame87.jpg', 'temporary_images/frame88.jpg', 'temporary_images/frame89.jpg', 'temporary_images/frame90.jpg', 'temporary_images/frame91.jpg', 'temporary_images/frame92.jpg', 'temporary_images/frame93.jpg', 'temporary_images/frame94.jpg', 'temporary_images/frame95.jpg', 'temporary_images/frame96.jpg', 'temporary_images/frame97.jpg', 'temporary_images/frame98.jpg', 'temporary_images/frame99.jpg', 'temporary_images/frame100.jpg', 'temporary_images/frame101.jpg', 'temporary_images/frame102.jpg', 'temporary_images/frame103.jpg', 'temporary_images/frame104.jpg', 'temporary_images/frame105.jpg', 'temporary_images/frame106.jpg', 'temporary_images/frame107.jpg', 'temporary_images/frame108.jpg', 'temporary_images/frame109.jpg', 'temporary_images/frame110.jpg', 'temporary_images/frame111.jpg', 'temporary_images/frame112.jpg', 'temporary_images/frame113.jpg', 'temporary_images/frame114.jpg', 'temporary_images/frame115.jpg', 'temporary_images/frame116.jpg', 'temporary_images/frame117.jpg', 'temporary_images/frame118.jpg', 'temporary_images/frame119.jpg', 'temporary_images/frame120.jpg', 'temporary_images/frame121.jpg', 'temporary_images/frame122.jpg', 'temporary_images/frame123.jpg', 'te ...
# 2023-03-16 17:23:15.708981: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-16 17:23:15.766618: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 215ms/step
# 2023-03-16 17:23:17.741113: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-16 17:23:17.793185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 2023-03-16 17:23:17.981716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-16 17:23:18.024764: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
#
#
# .........................
#
#  a baby is playing on a
#
# .........................
#
# It took 5.10 seconds to generate caption
# 1   HIToolbox                           0x00000001b80bed4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b7f98230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b7f98184 _ZN15MenuBarInstance14EnableAutoShowEv + 56
# 4   HIToolbox                           0x00000001b7f3b310 SetMenuBarObscured + 372
# 5   HIToolbox                           0x00000001b7f3aee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 6   HIToolbox                           0x00000001b7f34fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 7   HIToolbox                           0x00000001b7efbcd0 _NotifyEventLoopObservers + 176
# 8   HIToolbox                           0x00000001b7f3496c AcquireEventFromQueue + 432
# 9   HIToolbox                           0x00000001b7f23c84 ReceiveNextEventCommon + 320
# 10  HIToolbox                           0x00000001b7f23b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 11  AppKit                              0x00000001b1ac984c _DPSNextEvent + 632
# 12  AppKit                              0x00000001b1ac89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 13  cv2.abi3.so                         0x0000000146706d2c cvWaitKey + 344
# 14  cv2.abi3.so                         0x0000000146700e64 _ZN2cv9waitKeyExEi + 168
# 15  cv2.abi3.so                         0x0000000146700f5c _ZN2cv7waitKeyEi + 48
# 16  cv2.abi3.so                         0x0000000145cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 17  python3.10                          0x0000000102aaf788 cfunction_call + 80
# 18  python3.10                          0x0000000102a5bc30 _PyObject_MakeTpCall + 616
# 19  python3.10                          0x0000000102b52948 call_function + 676
# 20  python3.10                          0x0000000102b4e490 _PyEval_EvalFrameDefault + 26040
# 21  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 22  python3.10                          0x0000000102b52820 call_function + 380
# 23  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 24  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 25  python3.10                          0x0000000102b46e18 PyEval_EvalCode + 120
# 26  python3.10                          0x0000000102b42b18 builtin_exec + 836
# 27  python3.10                          0x0000000102ab04e4 cfunction_vectorcall_FASTCALL + 200
# 28  python3.10                          0x0000000102b52820 call_function + 380
# 29  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 30  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 31  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 32  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 33  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 34  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 35  python3.10                          0x0000000102a74eac gen_send + 52
# 36  python3.10                          0x0000000102a692e4 method_vectorcall_O + 152
# 37  python3.10                          0x0000000102b52820 call_function + 380
# 38  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 39  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 40  python3.10                          0x0000000102b52820 call_function + 380
# 41  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 42  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 43  python3.10                          0x0000000102b52820 call_function + 380
# 44  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 45  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 46  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 47  python3.10                          0x0000000102a5c470 PyVectorcall_Call + 156
# 48  python3.10                          0x0000000102b4e808 _PyEval_EvalFrameDefault + 26928
# 49  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 50  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 51  python3.10                          0x0000000102b52820 call_function + 380
# 52  python3.10                          0x0000000102b4e570 _PyEval_EvalFrameDefault + 26264
# 53  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 54  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 55  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 56  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 57  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 58  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 59  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 60  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 61  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 62  _asyncio.cpython-310-darwin.so      0x0000000104148080 task_step + 548
# 63  _asyncio.cpython-310-darwin.so      0x0000000104148cf8 task_wakeup + 136
# 64  python3.10                          0x0000000102ab0150 cfunction_vectorcall_O + 252
# 65  python3.10                          0x0000000102b6bc70 context_run + 348
# 66  python3.10                          0x0000000102ab03a8 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 67  python3.10                          0x0000000102b4e808 _PyEval_EvalFrameDefault + 26928
# 68  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 69  python3.10                          0x0000000102b52820 call_function + 380
# 70  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 71  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 72  python3.10                          0x0000000102b52820 call_function + 380
# 73  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 74  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 75  python3.10                          0x0000000102b52820 call_function + 380
# 76  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 77  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 78  python3.10                          0x0000000102b52820 call_function + 380
# 79  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 80  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 81  python3.10                          0x0000000102b52820 call_function + 380
# 82  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 83  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 84  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 85  python3.10                          0x0000000102b52820 call_function + 380
# 86  python3.10                          0x0000000102b4e490 _PyEval_EvalFrameDefault + 26040
# 87  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 88  python3.10                          0x0000000102b46e18 PyEval_EvalCode + 120
# 89  python3.10                          0x0000000102b42b18 builtin_exec + 836
# 90  python3.10                          0x0000000102ab04e4 cfunction_vectorcall_FASTCALL + 200
# 91  python3.10                          0x0000000102b52820 call_function + 380
# 92  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 93  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 94  python3.10                          0x0000000102b52820 call_function + 380
# 95  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 96  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 97  python3.10                          0x0000000102bc5d60 pymain_run_module + 272
# 98  python3.10                          0x0000000102bc5410 Py_RunMain + 1584
# 99  python3.10                          0x0000000102bc6858 pymain_main + 1284
# 100 python3.10                          0x0000000102a04754 main + 56
# 101 dyld                                0x00000001ae43be50 start + 2544
# 1   HIToolbox                           0x00000001b80bed4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001b7f98230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001b7f9c380 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 104
# 4   HIToolbox                           0x00000001b7efc4c0 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1092
# 5   HIToolbox                           0x00000001b7efb940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 6   HIToolbox                           0x00000001b7efb7d0 SendEventToEventTargetWithOptions + 44
# 7   HIToolbox                           0x00000001b7f3b9cc _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 472
# 8   HIToolbox                           0x00000001b7efc968 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2284
# 9   HIToolbox                           0x00000001b7efb940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 10  HIToolbox                           0x00000001b7f11bb8 SendEventToEventTarget + 40
# 11  AppKit                              0x00000001b1ac8f00 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 2044
# 12  cv2.abi3.so                         0x0000000146706d2c cvWaitKey + 344
# 13  cv2.abi3.so                         0x0000000146700e64 _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x0000000146700f5c _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x0000000145cc98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.10                          0x0000000102aaf788 cfunction_call + 80
# 17  python3.10                          0x0000000102a5bc30 _PyObject_MakeTpCall + 616
# 18  python3.10                          0x0000000102b52948 call_function + 676
# 19  python3.10                          0x0000000102b4e490 _PyEval_EvalFrameDefault + 26040
# 20  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 21  python3.10                          0x0000000102b52820 call_function + 380
# 22  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 23  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 24  python3.10                          0x0000000102b46e18 PyEval_EvalCode + 120
# 25  python3.10                          0x0000000102b42b18 builtin_exec + 836
# 26  python3.10                          0x0000000102ab04e4 cfunction_vectorcall_FASTCALL + 200
# 27  python3.10                          0x0000000102b52820 call_function + 380
# 28  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 29  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 30  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 31  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 32  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 33  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 34  python3.10                          0x0000000102a74eac gen_send + 52
# 35  python3.10                          0x0000000102a692e4 method_vectorcall_O + 152
# 36  python3.10                          0x0000000102b52820 call_function + 380
# 37  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 38  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 39  python3.10                          0x0000000102b52820 call_function + 380
# 40  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 41  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 42  python3.10                          0x0000000102b52820 call_function + 380
# 43  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 44  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 45  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 46  python3.10                          0x0000000102a5c470 PyVectorcall_Call + 156
# 47  python3.10                          0x0000000102b4e808 _PyEval_EvalFrameDefault + 26928
# 48  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 49  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 50  python3.10                          0x0000000102b52820 call_function + 380
# 51  python3.10                          0x0000000102b4e570 _PyEval_EvalFrameDefault + 26264
# 52  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 53  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 54  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 55  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 56  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 57  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 58  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 59  python3.10                          0x0000000102b4a6b8 _PyEval_EvalFrameDefault + 10208
# 60  python3.10                          0x0000000102a748d8 gen_send_ex2 + 524
# 61  _asyncio.cpython-310-darwin.so      0x0000000104148080 task_step + 548
# 62  _asyncio.cpython-310-darwin.so      0x0000000104148cf8 task_wakeup + 136
# 63  python3.10                          0x0000000102ab0150 cfunction_vectorcall_O + 252
# 64  python3.10                          0x0000000102b6bc70 context_run + 348
# 65  python3.10                          0x0000000102ab03a8 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 66  python3.10                          0x0000000102b4e808 _PyEval_EvalFrameDefault + 26928
# 67  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 68  python3.10                          0x0000000102b52820 call_function + 380
# 69  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 70  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 71  python3.10                          0x0000000102b52820 call_function + 380
# 72  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 73  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 74  python3.10                          0x0000000102b52820 call_function + 380
# 75  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 76  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 77  python3.10                          0x0000000102b52820 call_function + 380
# 78  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 79  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 80  python3.10                          0x0000000102b52820 call_function + 380
# 81  python3.10                          0x0000000102b4e468 _PyEval_EvalFrameDefault + 26000
# 82  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 83  python3.10                          0x0000000102a5f2e8 method_vectorcall + 164
# 84  python3.10                          0x0000000102b52820 call_function + 380
# 85  python3.10                          0x0000000102b4e490 _PyEval_EvalFrameDefault + 26040
# 86  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 87  python3.10                          0x0000000102b46e18 PyEval_EvalCode + 120
# 88  python3.10                          0x0000000102b42b18 builtin_exec + 836
# 89  python3.10                          0x0000000102ab04e4 cfunction_vectorcall_FASTCALL + 200
# 90  python3.10                          0x0000000102b52820 call_function + 380
# 91  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 92  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 93  python3.10                          0x0000000102b52820 call_function + 380
# 94  python3.10                          0x0000000102b4e500 _PyEval_EvalFrameDefault + 26152
# 95  python3.10                          0x0000000102b47634 _PyEval_Vector + 2028
# 96  python3.10                          0x0000000102bc5d60 pymain_run_module + 272
# 97  python3.10                          0x0000000102bc5410 Py_RunMain + 1584
# 98  python3.10                          0x0000000102bc6858 pymain_main + 1284
# 99  python3.10                          0x0000000102a04754 main + 56
# 100 dyld                                0x00000001ae43be50 start + 2544
